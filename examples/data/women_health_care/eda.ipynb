# %%
import pandas as pd
import os

# %%
DATASET_DIR = '.'

# %%
features = pd.read_csv('multilabel_data.csv.zip')
labels = pd.read_csv('multilabel_labels.csv')
labels.drop(columns='id', inplace=True)
# Out:
# /tmp/ipykernel_99936/1940777154.py:1: DtypeWarning: Columns (329,331,333,336,338,344,345,346,348,354,355,356,357,358,361,362,364,367,372,377,380,383,385,387,390,392,399,400,406,408,409,413,416,418,419,431,433,437,438,442,448,449,450,453,457,464,473,478,479,481,483,485,486,489,492,495,496,497,498,499,500,503,507,508,510,511,514,515,517,519,520,521,522,523,524,526,527,530,534,537,538,539,541,544,547,548,549,550,551,557,558,560,564,569,572,573,576,577,579,583,596,597,598,600,601,602,604,605,606,608,609,613,619,620,625,627,628,629,631,632,633,636,641,642,643,645,646,647,648,651,655,661,662,665,668,675,676,679,682,685,687,689,690,691,694,698,701,702,703,706,711,712,713,719,720,721,733,735,737,738,742,746,747,748,749,752,754,755,760,764,768,770,781,782,789,797,807,812,814,817,818,822,823,824,825,832,840,843,844,845,850,853,857,858,861,867,868,873,874,876,877,879,880,881,883,886,890,893,897,899,900,901,902,904,905,908,909,910,912,913,914,915,916,922,923,931,933,935,937,939,942,943,946,951,9
# ...

# %%
label_names = labels.columns.values

# %%
for label_name in label_names:
    print(f"{labels[label_name].value_counts()}")
# Out:
# 0    7735
# 1    6909
# Name: service_a, dtype: int64
# 0    9792
# 1    4852
# Name: service_b, dtype: int64
# 0    10776
# 1     3868
# Name: service_c, dtype: int64
# 0    14419
# 1      225
# Name: service_d, dtype: int64
# 0    13899
# 1      745
# Name: service_e, dtype: int64
# 0    14216
# 1      428
# Name: service_f, dtype: int64
# 0    13880
# 1      764
# Name: service_g, dtype: int64
# 0    10278
# 1     4366
# Name: service_h, dtype: int64
# 0    14402
# 1      242
# Name: service_i, dtype: int64
# 1    12445
# 0     2199
# Name: service_j, dtype: int64
# 1    11409
# 0     3235
# Name: service_k, dtype: int64
# 0    13078
# 1     1566
# Name: service_l, dtype: int64
# 0    13346
# 1     1298
# Name: service_m, dtype: int64
# 0    12032
# 1     2612
# Name: service_n, dtype: int64

# %%
data = pd.concat([features, labels], axis=1)

# %%
data
# Out:
#           id release  n_0000  n_0001    n_0002  n_0003  n_0004    n_0005  \
# 0      11193       a     NaN     NaN  0.025449     NaN     NaN  0.368421
# 1      11382       a     NaN     NaN  0.031297     NaN     NaN  0.315789
# 2      16531       a     NaN     NaN  0.024475     NaN     NaN  0.342105
# 3       1896       a     NaN     NaN  0.041694     NaN     NaN  0.447368
# 4      18262       c     NaN     NaN  0.038120     NaN     NaN  0.315789
# ...      ...     ...     ...     ...       ...     ...     ...       ...
# 14639   4114       a     NaN     NaN  0.026532     NaN     NaN  0.500000
# 14640   5305       a     NaN     NaN  0.035846     NaN     NaN  0.342105
# 14641  17461       c     NaN     NaN  0.060212     NaN     NaN  0.368421
# 14642  12373       b     NaN     NaN  0.020576     NaN     NaN  0.315789
# 14643   5968       a     NaN     NaN  0.037254     NaN     NaN  0.526316
#
#        n_0006  n_0007  ...  service_e  service_f  service_g  service_h  \
# ...

# %%
train_data, test_data = train_test_split(
    data, 
    test_size=TEST_SIZE,  
    random_state=RANDOM_STATE
)

print(f'Data is splitted. Parts sizes: train_data = {train_data.shape}, test_data = {test_data.shape}')

train_data.head()
